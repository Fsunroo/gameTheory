# %%
MAX = 30
CHOICE_RANGE = [i for i in range(MAX)]

# %%
def Win(STATE):
    STATE = list(STATE)
    mean = sum(STATE)/ len(STATE)
    delta = list(map(lambda x: abs(x-(mean/3)),STATE))

    if min(delta) == delta[0] :
        return 100 /(len(delta)-len(set(delta))+1)
    else:
        return 0

# %%
All_Stats = []
for me in CHOICE_RANGE:
    result =0
    for op1 in CHOICE_RANGE:
        for op2 in CHOICE_RANGE:
            for op3 in CHOICE_RANGE:
                result+=Win((me,op1,op2,op3))
    All_Stats.append(result)

# %%
All_Stats = []
for me in CHOICE_RANGE:
    result =0
    for op1 in CHOICE_RANGE:
        for op2 in CHOICE_RANGE:
            for op3 in CHOICE_RANGE:
                for op4 in CHOICE_RANGE:
                    for op5 in CHOICE_RANGE:

                        result+=Win((me,op1,op2,op3,op4,op5))
    All_Stats.append(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-bfe07ef7141a> in <module>
#       8                     for op4 in CHOICE_RANGE:
#       9
# ---> 10                         result+=Win((me,op1,op2,op3,op4,op5))
#      11     All_Stats.append(result)
#      12
#
# NameError: name 'op5' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(All_Stats)

# %%
All_Stats.index(max(All_Stats))
# Out:
# 4
